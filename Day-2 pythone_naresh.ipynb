# %%
import numpy as np

# %%
num = np.array([12,34,56,78,97,65,34])

# %%
num.mean()
# Out:
# 53.714285714285715

# %%
np.mean(num)
# Out:
# 53.714285714285715

# %%
sum(num)/len(num)
# Out:
# 53.714285714285715

# %%
np.median(num)
# Out:
# 56.0

# %%
np.append(num,80)
# Out:
# array([12, 34, 56, 78, 97, 65, 34, 80])

# %%
print('h')
# Out:
# h

# %%
np.median(num)
# Out:
# 56.0

# %%
num
# Out:
# array([12, 34, 56, 78, 97, 65, 34])

# %%
np.append(num,80)
num
np.median(num)
# Out:
# 56.0

# %%
num = np.array([12,23,34,45,65,98,65,43])

# %%
np.sort(num)
# Out:
# array([12, 23, 34, 43, 45, 65, 65, 98])

# %%
np.median(num)
# Out:
# 44.0

# %% [markdown]
# ##mode

# %%
import pandas as pd

# %%
gender = pd.Series(['m','m','f','m','f','m','m','m'])

# %%
gender.value_counts()
# Out:
# m    6
# f    2
# dtype: int64

# %%
gender.mode()
# Out:
# 0    m
# dtype: object

# %%
age = pd.Series([12,32,12,32,12,32,54,34,35,54,76,])

# %%
age.value_counts()
# Out:
# 12    3
# 32    3
# 54    2
# 76    1
# 35    1
# 34    1
# dtype: int64

# %%
age.mode()
# Out:
# 0    12
# 1    32
# dtype: int64

# %%
# midrange = (high + low)/2

# %%
(num.max()+num.min())/2
# Out:
# 55.0

# %%
## mean absolute deviation

# %%
sum(abs(num - np.mean(num)))/len(num)
# Out:
# 20.90625

# %%
# if all values are same then absolute deviatoin is zero. it means that feature will not affect output or it is not imp

# %%
## variance

# %%
np.mean((num-np.mean(num))**2)
# Out:
# 653.609375

# %%
## Standard deviation
# square root of variance = standard deviation

# %%
np.sqrt(np.mean((num-np.mean(num))**2))
# Out:
# 25.56578524121643

# %%
np.std(num)
# Out:
# 25.56578524121643

# %%
num.std()
# Out:
# 25.56578524121643

# %%
# range = max - min

# %%
## for getting data sets 
#- statista.org
#- data.gov.in
#- cricsheet

# %%
# Data Operations

# %%
import os 
os.getcwd()
# Out:
# 'C:\\Users\\ADMIN'

# %%
# import the data

# %%
df = pd.read_csv('demo.csv')

# %%
df
# Out:
#               टाइमस्टँप  roll_num          name   middlename       surname  \
# 0   30/05/2023 11:02:32   2201013      Swaroop      Jitendra        Bankar
# 1   30/05/2023 11:02:47  22201055          Isha      Praveen         Hosur
# 2   30/05/2023 11:02:52   2201071       Pranav        Girish         Joshi
# 3   30/05/2023 11:02:54   2201049         Kunal        Vijay        Golani
# 4   30/05/2023 11:03:00   2201070        Naresh      prakash         Joshi
# 5   30/05/2023 11:03:02   2201041       Shreyas       Sanjay  Dharashivkar
# 6   30/05/2023 11:03:05   2201068    Maitreyee        Mahesh         Joshi
# 7   30/05/2023 11:03:16   2201069       Mrunal         Vivek         Joshi
# 8   30/05/2023 11:03:29   2201043      Vaibhav        Girish         Dixit
# 9   30/05/2023 11:03:32   2201065       Aakash        Satish        Jagtap
# 10  30/05/2023 11:03:35   2201063      Sanket        Rajaram        Jadhav
# ...

# %%
df.shape
# Out:
# (56, 11)

# %%
list(df.columns)
# Out:
# ['टाइमस्टँप',
#  'roll_num',
#  'name',
#  'middlename',
#  'surname',
#  'age',
#  'marks',
#  'gender',
#  'favorite_sport',
#  'native_city',
#  'year_of_passing_10th']

# %%
#top 5 entries
df.head()
# Out:
#              टाइमस्टँप  roll_num      name middlename surname   age  \
# 0  30/05/2023 11:02:32   2201013  Swaroop    Jitendra  Bankar  21.0
# 1  30/05/2023 11:02:47  22201055      Isha    Praveen   Hosur  22.0
# 2  30/05/2023 11:02:52   2201071   Pranav      Girish   Joshi  22.0
# 3  30/05/2023 11:02:54   2201049     Kunal      Vijay  Golani   NaN
# 4  30/05/2023 11:03:00   2201070    Naresh    prakash   Joshi  22.0
#
#        marks  gender favorite_sport native_city year_of_passing_10th
# 0        7.9    Male      Badminton        Pune                 2017
# 1       8.64  Female       Swimming        Pune                 2017
# 2        8.2    Male        Cricket        Pune                 2017
# 3  8.36 SGPA    Male        Cricket       Surat                 2017
# 4         85    Male        cricket  aurangabad                 2017

# %%
df.tail()
# Out:
#               टाइमस्टँप  roll_num          name middlename   surname   age  \
# 51  30/05/2023 11:07:08   2201083        SUYASH      DILIP    KAMBLE  23.0
# 52  30/05/2023 11:07:11   2201007  Radhesahyam      Girish   Ambhore  22.0
# 53  30/05/2023 11:07:26   2201054       Viresh   Nandkumar  Hiremath   NaN
# 54  30/05/2023 11:07:39   2201029       Tasmay   Ghanshyam  Daimiwal  22.0
# 55  30/05/2023 11:07:42   2201075       vaibhav  Bharatrao     Kadam  23.0
#
#    marks gender favorite_sport native_city year_of_passing_10th
# 51   7.7   Male    MOTORSPORTS      SASWAD                   80
# 52   8.9   Male        Cricket        Pune                 2017
# 53   7.9   Male        Cricket      Sangli                 2016
# 54   7.8   Male       Football        Pune                 2017
# 55    95   Male          Chess       Jalna                 2016

# %%
### slicing of data [row seq, column seq]

# %%
df.iloc[3:8,2:5]
# Out:
#          name middlename       surname
# 3       Kunal      Vijay        Golani
# 4      Naresh    prakash         Joshi
# 5     Shreyas     Sanjay  Dharashivkar
# 6  Maitreyee      Mahesh         Joshi
# 7     Mrunal       Vivek         Joshi

# %%
df.iloc[30:,2:6]
# Out:
#             name   middlename   surname   age
# 30        Aditya        Ashok    Kodape  22.0
# 31        Mayur   Sanjaykumar    Biyale   NaN
# 32         RIYA        PRAMOD     BHIDE  23.0
# 33     Utkarsha      Shridhar    Joshi   22.0
# 34    Shreyash         Sanjay  Amrutkar  21.0
# 35        Aditya      Sanjay     Jadhav  23.0
# 36     Aniruddha       Rajesh    Kakade   NaN
# 37         Yash       Subhash   Bombale  21.0
# 38       Anshika                          NaN
# 39       keshvi        kumari  khanduja  22.0
# 40       Ritika      Surendra     Ahuja  22.0
# 41        Omkar         Vijay     Borse  21.0
# 42        Rohit         Sunil    Jadhav  23.0
# 43         Amogh     Shrikant     Datar  22.0
# 44        Gaurav        Sunil   Bangade  21.0
# 45        Eshan        Ashish     Desle  24.0
# 46       Manasi     Shreedhar    Jadhav  22.0
# 47      Bhargav    Nandkishor    Jagtap   NaN
# 48      srishti        Rajesh      Jain  23.0
# ...

# %%
x=df.iloc[3:,:7]
x
# Out:
#               टाइमस्टँप  roll_num          name   middlename       surname  \
# 3   30/05/2023 11:02:54   2201049         Kunal        Vijay        Golani
# 4   30/05/2023 11:03:00   2201070        Naresh      prakash         Joshi
# 5   30/05/2023 11:03:02   2201041       Shreyas       Sanjay  Dharashivkar
# 6   30/05/2023 11:03:05   2201068    Maitreyee        Mahesh         Joshi
# 7   30/05/2023 11:03:16   2201069       Mrunal         Vivek         Joshi
# 8   30/05/2023 11:03:29   2201043      Vaibhav        Girish         Dixit
# 9   30/05/2023 11:03:32   2201065       Aakash        Satish        Jagtap
# 10  30/05/2023 11:03:35   2201063      Sanket        Rajaram        Jadhav
# 11  30/05/2023 11:03:38   2201038     Priyanka         Popat       Dhanave
# 12  30/05/2023 11:03:40   2201097        Ranjit      Prakash        Kokare
# 13  30/05/2023 11:03:41   2201032         Aditi      Mangesh           Deo
# ...

# %%
df.loc[2]
# Out:
# टाइमस्टँप               30/05/2023 11:02:52
# roll_num                            2201071
# name                                Pranav
# middlename                           Girish
# surname                               Joshi
# age                                      22
# marks                                   8.2
# gender                                 Male
# favorite_sport                      Cricket
# native_city                            Pune
# year_of_passing_10th                   2017
# Name: 2, dtype: object

# %%
df.loc[:4,'name']
# Out:
# 0    Swaroop
# 1        Isha
# 2     Pranav
# 3       Kunal
# 4      Naresh
# Name: name, dtype: object

# %%
df.loc[:,['name','middlename','surname']]
# Out:
#             name   middlename       surname
# 0       Swaroop      Jitendra        Bankar
# 1           Isha      Praveen         Hosur
# 2        Pranav        Girish         Joshi
# 3          Kunal        Vijay        Golani
# 4         Naresh      prakash         Joshi
# 5        Shreyas       Sanjay  Dharashivkar
# 6     Maitreyee        Mahesh         Joshi
# 7        Mrunal         Vivek         Joshi
# 8       Vaibhav        Girish         Dixit
# 9        Aakash        Satish        Jagtap
# 10      Sanket        Rajaram        Jadhav
# 11     Priyanka         Popat       Dhanave
# 12        Ranjit      Prakash        Kokare
# 13         Aditi      Mangesh           Deo
# 14         Tejas         Arun     Dhanuskar
# 15      hritika   chandrakant          koli
# 16      Harshada        Vijay      Bhalekar
# 17    Sanskriti             .         Gupta
# 18     Akanksha        Bharat        Kadlag
# 19        Parth        Dinkar     Deshpande
# ...

# %%
df['native_city']
# Out:
# 0              Pune
# 1              Pune
# 2              Pune
# 3             Surat
# 4        aurangabad
# 5              Pune
# 6              Pune
# 7              Pune
# 8            Mumbai
# 9              Pune
# 10        Chicnholi
# 11             Pune
# 12          Solapur
# 13             Pune
# 14           Nagpur
# 15             pune
# 16        Sangamner
# 17         Varanasi
# 18           Sinnar
# 19            Akola
# 20           Gondia
# 21             pune
# 22         Kolhapur
# 23          Kolkata
# 24         Kolhapur
# 25             Pune
# 26             pune
# 27             pune
# 28           mumbai
# 29         Amravati
# 30          Satefal
# 31             Beed
# 32           NAGPUR
# 33      Aurangabad
# 34           Nashik
# 35           Nashik
# 36         Kolhapur
# 37             Pune
# 38             Pune
# 39          neemuct
# 40            Dhule
# 41           Nashik
# 42        Sangamner
# 43             Pune
# 44           Warora
# ...

# %%
df[['name','surname']]
# Out:
#             name       surname
# 0       Swaroop         Bankar
# 1           Isha         Hosur
# 2        Pranav          Joshi
# 3          Kunal        Golani
# 4         Naresh         Joshi
# 5        Shreyas  Dharashivkar
# 6     Maitreyee          Joshi
# 7        Mrunal          Joshi
# 8       Vaibhav          Dixit
# 9        Aakash         Jagtap
# 10      Sanket          Jadhav
# 11     Priyanka        Dhanave
# 12        Ranjit        Kokare
# 13         Aditi           Deo
# 14         Tejas     Dhanuskar
# 15      hritika           koli
# 16      Harshada      Bhalekar
# 17    Sanskriti          Gupta
# 18     Akanksha         Kadlag
# 19        Parth      Deshpande
# 20         Ajay        Koronde
# 21        Tejas         kashid
# 22      Pranjal        Shintre
# 23        Debraj           Das
# 24       Shreya          Korde
# 25        Vedant    Chandratre
# 26       Ganesh           Kore
# 27        Parth      Agnihotri
# 28        Mihir      chaudhary
# ...

# %%
df.iloc[[2,14,54,32],[2,4,6]]
# Out:
#        name    surname      marks
# 2   Pranav       Joshi        8.2
# 14    Tejas  Dhanuskar         90
# 54  Tasmay    Daimiwal        7.8
# 32    RIYA       BHIDE  7.32 SGPA

# %%
df.drop([2,5,8,6,54,42])    # droped no of rows
# Out:
#               टाइमस्टँप  roll_num          name   middlename     surname  \
# 0   30/05/2023 11:02:32   2201013      Swaroop      Jitendra      Bankar
# 1   30/05/2023 11:02:47  22201055          Isha      Praveen       Hosur
# 3   30/05/2023 11:02:54   2201049         Kunal        Vijay      Golani
# 4   30/05/2023 11:03:00   2201070        Naresh      prakash       Joshi
# 7   30/05/2023 11:03:16   2201069       Mrunal         Vivek       Joshi
# 9   30/05/2023 11:03:32   2201065       Aakash        Satish      Jagtap
# 10  30/05/2023 11:03:35   2201063      Sanket        Rajaram      Jadhav
# 11  30/05/2023 11:03:38   2201038     Priyanka         Popat     Dhanave
# 12  30/05/2023 11:03:40   2201097        Ranjit      Prakash      Kokare
# 13  30/05/2023 11:03:41   2201032         Aditi      Mangesh         Deo
# 14  30/05/2023 11:03:43   2201040         Tejas         Arun   Dhanuskar
# 15  30/05/2023 11:03:45   2201098      hritika   chandrakant        koli
# ...

# %%
df.drop(['gender','name'],axis=1)
# Out:
#               टाइमस्टँप  roll_num   middlename       surname   age      marks  \
# 0   30/05/2023 11:02:32   2201013     Jitendra        Bankar  21.0        7.9
# 1   30/05/2023 11:02:47  22201055      Praveen         Hosur  22.0       8.64
# 2   30/05/2023 11:02:52   2201071       Girish         Joshi  22.0        8.2
# 3   30/05/2023 11:02:54   2201049        Vijay        Golani   NaN  8.36 SGPA
# 4   30/05/2023 11:03:00   2201070      prakash         Joshi  22.0         85
# 5   30/05/2023 11:03:02   2201041       Sanjay  Dharashivkar  22.0        7.9
# 6   30/05/2023 11:03:05   2201068       Mahesh         Joshi  22.0       9.25
# 7   30/05/2023 11:03:16   2201069        Vivek         Joshi  21.0        88%
# 8   30/05/2023 11:03:29   2201043       Girish         Dixit  23.0         80
# 9   30/05/2023 11:03:32   2201065       Satish        Jagtap  21.0       82.4
# 10  30/05/2023 11:03:35   2201063      Rajaram        Jadhav   NaN      98.21
# ...

# %%
df.drop(['gender','name'],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['टाइमस्टँप', 'roll_num', 'middlename', 'surname', 'age', 'marks',
#        'favorite_sport', 'native_city', 'year_of_passing_10th'],
#       dtype='object')

# %%
df
# Out:
#               टाइमस्टँप  roll_num   middlename       surname   age      marks  \
# 0   30/05/2023 11:02:32   2201013     Jitendra        Bankar  21.0        7.9
# 1   30/05/2023 11:02:47  22201055      Praveen         Hosur  22.0       8.64
# 2   30/05/2023 11:02:52   2201071       Girish         Joshi  22.0        8.2
# 3   30/05/2023 11:02:54   2201049        Vijay        Golani   NaN  8.36 SGPA
# 4   30/05/2023 11:03:00   2201070      prakash         Joshi  22.0         85
# 5   30/05/2023 11:03:02   2201041       Sanjay  Dharashivkar  22.0        7.9
# 6   30/05/2023 11:03:05   2201068       Mahesh         Joshi  22.0       9.25
# 7   30/05/2023 11:03:16   2201069        Vivek         Joshi  21.0        88%
# 8   30/05/2023 11:03:29   2201043       Girish         Dixit  23.0         80
# 9   30/05/2023 11:03:32   2201065       Satish        Jagtap  21.0       82.4
# 10  30/05/2023 11:03:35   2201063      Rajaram        Jadhav   NaN      98.21
# ...

# %%
df.dtypes
# Out:
# टाइमस्टँप                object
# roll_num                  int64
# middlename               object
# surname                  object
# age                     float64
# marks                    object
# favorite_sport           object
# native_city              object
# year_of_passing_10th     object
# dtype: object

# %%
df.describe()
# Out:
#            roll_num      age
# count  5.600000e+01  38.0000
# mean   2.558196e+06  22.0000
# std    2.672613e+06   0.7711
# min    2.201002e+06  21.0000
# 25%    2.201029e+06  21.2500
# 50%    2.201052e+06  22.0000
# 75%    2.201075e+06  22.0000
# max    2.220106e+07  24.0000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   टाइमस्टँप             56 non-null     object
#  1   roll_num              56 non-null     int64
#  2   middlename            56 non-null     object
#  3   surname               56 non-null     object
#  4   age                   38 non-null     float64
#  5   marks                 56 non-null     object
#  6   favorite_sport        56 non-null     object
#  7   native_city           56 non-null     object
#  8   year_of_passing_10th  56 non-null     object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 4.1+ KB

# %%
df.count()
# Out:
# टाइमस्टँप               56
# roll_num                56
# middlename              56
# surname                 56
# age                     38
# marks                   56
# favorite_sport          56
# native_city             56
# year_of_passing_10th    56
# dtype: int64

# %%
df.min()
# Out:
# टाइमस्टँप               30/05/2023 11:02:32
# roll_num                            2201002
# middlename
# surname
# age                                      21
# marks                                   100
# favorite_sport                            .
# native_city                           Akola
# year_of_passing_10th                   2014
# dtype: object

# %%
df.max()
# Out:
# टाइमस्टँप               30/05/2023 11:07:42
# roll_num                           22201055
# middlename                          prakash
# surname                                koli
# age                                      24
# marks                                 98.21
# favorite_sport                     voliball
# native_city                            pune
# year_of_passing_10th                     80
# dtype: object

# %%
df.sum()
# Out:
# टाइमस्टँप               30/05/2023 11:02:3230/05/2023 11:02:4730/05/20...
# roll_num                                                        143258998
# middlename              JitendraPraveenGirishVijayprakashSanjayMaheshV...
# surname                 BankarHosurJoshiGolaniJoshiDharashivkarJoshiJo...
# age                                                                   836
# marks                   7.98.648.28.36 SGPA857.99.2588%8082.498.2182.8...
# favorite_sport          BadmintonSwimmingCricketCricketcricketSwimming...
# native_city             PunePunePuneSurataurangabadPunePunePuneMumbaiP...
# year_of_passing_10th    2017201720172017201720172017201720152017201720...
# dtype: object

# %%
df.mean()
# Out:
# roll_num    2.558196e+06
# age         2.200000e+01
# dtype: float64

# %%
df.std()
# Out:
# roll_num    2.672613e+06
# age         7.710996e-01
# dtype: float64

# %%
df.median()
# Out:
# roll_num    2201052.5
# age              22.0
# dtype: float64

# %%
df['age'].mean()
# Out:
# 22.0

# %%
df['age'].max()
# Out:
# 24.0

# %%
df['age'].median()
# Out:
# 22.0

# %%
## String functins

# %%
df['surname'].str.upper()
# Out:
# 0           BANKAR
# 1            HOSUR
# 2            JOSHI
# 3           GOLANI
# 4            JOSHI
# 5     DHARASHIVKAR
# 6            JOSHI
# 7            JOSHI
# 8            DIXIT
# 9           JAGTAP
# 10          JADHAV
# 11         DHANAVE
# 12          KOKARE
# 13             DEO
# 14       DHANUSKAR
# 15            KOLI
# 16        BHALEKAR
# 17           GUPTA
# 18          KADLAG
# 19       DESHPANDE
# 20         KORONDE
# 21          KASHID
# 22         SHINTRE
# 23             DAS
# 24           KORDE
# 25      CHANDRATRE
# 26            KORE
# 27       AGNIHOTRI
# 28       CHAUDHARY
# 29           DETHE
# 30          KODAPE
# 31          BIYALE
# 32           BHIDE
# 33          JOSHI
# 34        AMRUTKAR
# 35          JADHAV
# 36          KAKADE
# 37         BOMBALE
# 38
# 39        KHANDUJA
# 40           AHUJA
# 41           BORSE
# 42          JADHAV
# 43           DATAR
# 44         BANGADE
# 45           DESLE
# 46          JADHAV
# 47          JAGTAP
# ...

# %%
df['surname'].str.swapcase()
# Out:
# 0           bANKAR
# 1            hOSUR
# 2            jOSHI
# 3           gOLANI
# 4            jOSHI
# 5     dHARASHIVKAR
# 6            jOSHI
# 7            jOSHI
# 8            dIXIT
# 9           jAGTAP
# 10          jADHAV
# 11         dHANAVE
# 12          kOKARE
# 13             dEO
# 14       dHANUSKAR
# 15            KOLI
# 16        bHALEKAR
# 17           gUPTA
# 18          kADLAG
# 19       dESHPANDE
# 20         kORONDE
# 21          KASHID
# 22         sHINTRE
# 23             dAS
# 24           kORDE
# 25      cHANDRATRE
# 26            kORE
# 27       aGNIHOTRI
# 28       CHAUDHARY
# 29           dETHE
# 30          kODAPE
# 31          bIYALE
# 32           bhide
# 33          jOSHI
# 34        aMRUTKAR
# 35          jADHAV
# 36          kAKADE
# 37         bOMBALE
# 38
# 39        KHANDUJA
# 40           aHUJA
# 41           bORSE
# 42          jADHAV
# 43           dATAR
# 44         bANGADE
# 45           dESLE
# 46          jADHAV
# 47          jAGTAP
# ...

# %%
#replace content of original column

# %%
df['surname']=df['surname'].str.title()
df['middlename']=df['middlename'].str.title()
df['native_city']=df['native_city'].str.title()

# %%
df['surname']=df['surname'].str.strip()
df['middlename']=df['middlename'].str.strip()
df['native_city']=df['native_city'].str.strip()
df['favorite_sport']=df['favorite_sport'].str.strip()

# %%
df[['surname','middlename','native_city']]
# Out:
#          surname   middlename    native_city
# 0         Bankar     Jitendra           Pune
# 1          Hosur      Praveen           Pune
# 2          Joshi       Girish           Pune
# 3         Golani        Vijay          Surat
# 4          Joshi      Prakash     Aurangabad
# 5   Dharashivkar       Sanjay           Pune
# 6          Joshi       Mahesh           Pune
# 7          Joshi        Vivek           Pune
# 8          Dixit       Girish         Mumbai
# 9         Jagtap       Satish           Pune
# 10        Jadhav      Rajaram      Chicnholi
# 11       Dhanave        Popat           Pune
# 12        Kokare      Prakash        Solapur
# 13           Deo      Mangesh           Pune
# 14     Dhanuskar         Arun         Nagpur
# 15          Koli  Chandrakant           Pune
# 16      Bhalekar        Vijay      Sangamner
# 17         Gupta            .       Varanasi
# 18        Kadlag       Bharat         Sinnar
# 19     Deshpande       Dinkar          Akola
# ...

# %%
df['surname'].str.startswith('A')
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27     True
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34     True
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40     True
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# 50    False
# 51    False
# 52     True
# 53    False
# 54    False
# 55    False
# Name: surname, dtype: bool

# %%
df['native_city'].mode()
# Out:
# 0    Pune
# dtype: object

# %%
df['favorite_sport'].value_counts()
# Out:
# Cricket          18
# Badminton         7
# cricket           4
# Football          4
# Swimming          4
# football          3
# swimming          2
# .                 2
# Chess             2
# badminton         2
# CRICKET           1
# Snocker           1
# Swimmng           1
# MOTORSPORTS       1
# TT_Badminton      1
# voliball          1
# Squash            1
# Power Lifting     1
# Name: favorite_sport, dtype: int64

# %%
df[df['age']>22]
# Out:
#               टाइमस्टँप  roll_num middlename surname   age      marks  \
# 8   30/05/2023 11:03:29   2201043     Girish   Dixit  23.0         80
# 32  30/05/2023 11:05:11   2201018     Pramod   Bhide  23.0  7.32 SGPA
# 35  30/05/2023 11:05:27   2201056     Sanjay  Jadhav  23.0         93
# 42  30/05/2023 11:05:56   2201061      Sunil  Jadhav  23.0  7.21 SGPA
# 45  30/05/2023 11:06:14   2201036     Ashish   Desle  24.0          7
# 48  30/05/2023 11:06:34   2201067     Rajesh    Jain  23.0        7.3
# 49  30/05/2023 11:06:41   2201088      Sunil   Karpe  23.0         80
# 51  30/05/2023 11:07:08   2201083      Dilip  Kamble  23.0        7.7
# 55  30/05/2023 11:07:42   2201075  Bharatrao   Kadam  23.0         95
#
#    favorite_sport native_city year_of_passing_10th
# 8          Squash      Mumbai                 2015
# 32        CRICKET      Nagpur                 2015
# 35        Cricket      Nashik                 2016
# 42        Cricket   Sangamner                 2016
# ...

# %%
df[(df['age']>22) & (df['native_city']=='Pune') ]
# Out:
#               टाइमस्टँप  roll_num middlename surname   age marks  \
# 45  30/05/2023 11:06:14   2201036     Ashish   Desle  24.0     7
#
#    favorite_sport native_city year_of_passing_10th
# 45        Cricket        Pune                 2014

# %%
df[(df['native_city']=='Pune') & (df['favorite_sport']=='Cricket')]['surname',]
# Out:
# 2       Joshi
# 9      Jagtap
# 21     Kashid
# 26       Kore
# 45      Desle
# 52    Ambhore
# Name: surname, dtype: object

# %%
## save data in deperate dataframe or export it

# %%
x = df[(df['native_city']=='Pune') & (df['favorite_sport']=='Cricket')]['surname']

# %%
x.to_csv('output.csv',index=False)
